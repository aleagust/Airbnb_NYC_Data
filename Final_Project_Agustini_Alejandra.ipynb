# %% [markdown]
# <center><h1>Capstone Project Creation</h1></center>
# <center><h3>IBM SkillsBuild Europe Delivery - Data Analytics</h3></center>
#
#
# # Pre-requisite
#
# * Understanding of Python, Power BI or Tableau
# * Understanding of Data Cleaning
# * Understanding Data Visualization
#
# #### Level of Exercise: Intermediate
#
# #### Duration: approximately 3 hours

# %% [markdown]
# ### Data Analytics of Airbnb Data:
#
# #### Objective:
#
# In this exericise, you will be performing Data Analytics on an Open Dataset dataset coming from Airbnb. Some of the tasks include
# - Data Cleaning.
# - Data Transformation
# - Data Visualization.
#
# #### Overview of Airbnb Data:
#
# People's main criteria when visiting new places are reasonable accommodation and food. Airbnb (Air-Bed-Breakfast) is an online marketplace created to meet this need of people by renting out their homes for a short term. They offer this facility at a relatively lower price than hotels. Further people worldwide prefer the homely and economical service offered by them. They offer services across various geographical locations
#
# #### Dataset Source
#
# YOu can get the dataset for this assessment using the following link: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
#
# This dataset contains information such as the neighborhood offering these services, room type, price,avaliabilty, reviews, service fee, cancellation policy and rules to use the house. This analysis will help airbnb in improving its services.
#
# So all the best for your Data Analytics Journey on Airbnb data!!!

# %% [markdown]
# ## Task 1: Data Loading (Python)
#
# 1. Read the csv file and load it into a pandas dataframe.
# 2. Display the first five rows of your dataframe.
# 3. Display the data types of the columns.

# %%
## Importing the libraries
import pandas as pd
import numpy as np 

## Visualisation

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
## Read the csv file
df = pd.read_csv('Airbnb_Open_Data.csv', low_memory=False)

# %%
## Display the first 5 rows
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
## Display the data types
print(df.dtypes)
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %%
## check the lenght of the data frame
len(df)
# Out:
# 102599

# %% [markdown]
# ## Task 2a: Data Cleaning (Any Tool)
#
# 1. Drop some of the unwanted columns. These include `host id`, `id`, `country` and `country code` from the dataset.
# 2. State the reason for not including these columns for your Data Analytics.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots before and after the elimination of the columns.

# %%
## Display the name of the columns
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
## Check the amount of columns
len(df.columns)
# Out:
# 26

# %%
## Drop some of the unwanted columns
df.drop(columns=['host id', 'id', 'country', 'country code', 'license'], axis=1, inplace=True)

# %%
## Check the amount of columns after the removal
len(df.columns)
# Out:
# 21

# %%
df.head(5)
# Out:
#                                                NAME host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host name neighbourhood group neighbourhood       lat      long  \
# 0  Madaline            Brooklyn    Kensington  40.64749 -73.97237
# 1     Jenna           Manhattan       Midtown  40.75362 -73.98377
# 2     Elise           Manhattan        Harlem  40.80902 -73.94190
# 3     Garry            Brooklyn  Clinton Hill  40.68514 -73.95976
# 4    Lyndon           Manhattan   East Harlem  40.79851 -73.94399
#
#   instant_bookable cancellation_policy        room type  ...  price  \
# ...

# %%
## These columns are not included for the data analytics because:
#  -The data refers to one country only, so we don't need the country information like 'CountryName' and 'CountryCode'.
#  -The analysis is made with data agregation and to identify each property or host individually is not necessary.

# %% [markdown]
# ## Task 2b: Data Cleaning (Python)
#
# - Check for missing values in the dataframe and display the count in ascending order. **If the values are missing, impute the values as per the datatype of the columns.**
# - Check whether there are any duplicate values in the dataframe and, if present, remove them.
# - Display the total number of records in the dataframe before and after removing the duplicates.

# %%
## Check for missing values in the dataframe and display the count in ascending order.
df.isnull().sum().sort_values()
# Out:
# room type                             0
# lat                                   8
# long                                  8
# neighbourhood                        16
# neighbourhood group                  29
# cancellation_policy                  76
# instant_bookable                    105
# number of reviews                   183
# Construction year                   214
# price                               247
# NAME                                250
# service fee                         273
# host_identity_verified              289
# calculated host listings count      319
# review rate number                  326
# host name                           406
# minimum nights                      409
# availability 365                    448
# reviews per month                 15879
# last review                       15893
# house_rules                       52131
# dtype: int64

# %%
## Impute the values as per the datatype of the columns. The missing values will be replaced using:
# -the median for numerical data
# -the mode for object data type.

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column].dtype):
        df[column] = df[column].fillna(df[column].median())
    elif df[column].dtype == 'object':
        df[column] = df[column].fillna(df[column].mode().iloc[0])

# %%
#Check if there are still any missing values:
df.isnull().sum().sort_values()
# Out:
# NAME                              0
# calculated host listings count    0
# review rate number                0
# reviews per month                 0
# last review                       0
# number of reviews                 0
# minimum nights                    0
# service fee                       0
# price                             0
# availability 365                  0
# Construction year                 0
# cancellation_policy               0
# instant_bookable                  0
# long                              0
# lat                               0
# neighbourhood                     0
# neighbourhood group               0
# host name                         0
# host_identity_verified            0
# room type                         0
# house_rules                       0
# dtype: int64

# %%
## Check whether there are any duplicate values in the dataframe and if present remove them.
df.shape
# Out:
# (102599, 21)

# %%
df.duplicated().sum()
# Out:
# 3461

# %%
df.drop_duplicates(inplace=True)

# %%
## Display the total number of records in the dataframe after removing the duplicates.
len(df)
# Out:
# 99138

# %% [markdown]
# ## Task 3: Data Transformation (Any Tool)
#
#
# - Rename the column `availability 365` to `days_booked`
# - Convert all column names to lowercase and replace the spaces in the column names with an underscore "_".
# - Remove the dollar sign and comma from the columns `price` and `service_fee`. If necessary, convert these two columns to the appropriate data type.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## Rename the column.
df.rename(columns={'availability 365': 'days_booked'}, inplace=True)
df.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
## Convert all column names to lowercase and replace the spaces with an underscore "_"
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
## Remove the dollar sign and comma from the columns. If necessary, convert these two columns to the appropriate data type.
print(df.dtypes)
# Out:
# name                               object
# host_identity_verified             object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# instant_bookable                     bool
# cancellation_policy                object
# room_type                          object
# construction_year                 float64
# price                              object
# service_fee                        object
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# review_rate_number                float64
# calculated_host_listings_count    float64
# days_booked                       float64
# house_rules                        object
# dtype: object

# %%
df['price'] = pd.to_numeric(df['price'].replace('[\$,]', '', regex=True))
df['service_fee'] = pd.to_numeric(df['service_fee'].replace('[\$,]', '', regex=True))
df[['price','service_fee']].head()
# Out:
#    price  service_fee
# 0    966          193
# 1    142           28
# 2    620          124
# 3    368           74
# 4    204           41

# %%
print(df.dtypes)
# Out:
# name                               object
# host_identity_verified             object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# instant_bookable                     bool
# cancellation_policy                object
# room_type                          object
# construction_year                 float64
# price                               int64
# service_fee                         int64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# review_rate_number                float64
# calculated_host_listings_count    float64
# days_booked                       float64
# house_rules                        object
# dtype: object

# %%
# Other inconsistencies were detected in the data needed for further analysis, so more data transformation actions need
# to be executed.

# %%
#Two of the neighbourhood groups are not written correctly. 
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens',
#        'Staten Island', 'Bronx'], dtype=object)

# %%
#Replace the 'manhatan' with 'Manhattan' and 'brookln' with 'Brooklyn' to get the right names:
df['neighbourhood_group'] = df['neighbourhood_group'].replace({'manhatan': 'Manhattan', 'brookln': 'Brooklyn'})
print(df['neighbourhood_group'].value_counts())
# Out:
# neighbourhood_group
# Manhattan        42393
# Brooklyn         40374
# Queens           12836
# Bronx             2615
# Staten Island      920
# Name: count, dtype: int64

# %%
#As shown below, the contruction year is a float data type and have decimals:
print(df['construction_year'].value_counts())
print('\nConstruction year column data type')
print(df['construction_year'].dtype)
# Out:
# construction_year
# 2012.0    5159
# 2014.0    5063
# 2008.0    5046
# 2006.0    5029
# 2020.0    5005
# 2019.0    5004
# 2009.0    4999
# 2010.0    4966
# 2003.0    4966
# 2022.0    4959
# 2005.0    4949
# 2007.0    4940
# 2015.0    4928
# 2017.0    4911
# 2011.0    4887
# 2018.0    4883
# 2021.0    4866
# 2004.0    4865
# 2016.0    4858
# 2013.0    4855
# Name: count, dtype: int64
#
# Construction year column data type
# float64

# %%
#Convert the data into integers to fix the problem and then check if the changes were made.
df.construction_year= df.construction_year.astype('int64')
print(df['construction_year'].value_counts())
print('\nConstruction year column data type')
print(df['construction_year'].dtype)
# Out:
# construction_year
# 2012    5159
# 2014    5063
# 2008    5046
# 2006    5029
# 2020    5005
# 2019    5004
# 2009    4999
# 2010    4966
# 2003    4966
# 2022    4959
# 2005    4949
# 2007    4940
# 2015    4928
# 2017    4911
# 2011    4887
# 2018    4883
# 2021    4866
# 2004    4865
# 2016    4858
# 2013    4855
# Name: count, dtype: int64
#
# Construction year column data type
# int64

# %% [markdown]
# ### Task 4: Exploratory Data Analysis (Any Tool)
#
# - List the count of various room types avaliable in the dataset.
# - Which room type has the most strict cancellation policy?
# - List the average price per neighborhood group, and highlight the most expensive neighborhood to rent from.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## List the count of various room types avaliable with Airbnb
print('Count of various room types avaliable with Airbnb:')
print(df['room_type'].value_counts())
# Out:
# Count of various room types avaliable with Airbnb:
# room_type
# Entire home/apt    51987
# Private room       44887
# Shared room         2149
# Hotel room           115
# Name: count, dtype: int64

# %%
## Which room type adheres to more strict cancellation policy?

#Filter the data selecting only the rooms with strict cancellation policy and then do the count:
strict_policy_filter = df[df['cancellation_policy'] == 'strict']
strict_policy_count = strict_policy_filter['room_type'].value_counts()
print("Count of strict cancellation policy for each room type:")
print(strict_policy_count)

#Calculating the room type that adheres to more strict cancellation policy:
most_strict = strict_policy_count.idxmax()
print('\nThe room type with more strict cancellation policy:')
print(most_strict)
# Out:
# Count of strict cancellation policy for each room type:
# room_type
# Entire home/apt    17238
# Private room       14936
# Shared room          718
# Hotel room            34
# Name: count, dtype: int64
#
# The room type with more strict cancellation policy:
# Entire home/apt

# %%
## List the prices by neighbourhood group and also mention which is the most expensive neighbourhood group for rentals

#Grouping the data by neighbourhood group and calculating the price mean:
average_price_per_neighborhood = df.groupby('neighbourhood_group')['price'].mean().round(2)\
.sort_values(ascending=False)
print("Average price per neighborhood group:")
print(average_price_per_neighborhood)

#Calculating the most expensive neighbourhood to rent from:
most_expensive_neighborhood = average_price_per_neighborhood.idxmax()
print("\nMost expensive neighbourhood to rent from:")
print(most_expensive_neighborhood)
# Out:
# Average price per neighborhood group:
# neighbourhood_group
# Queens           628.67
# Brooklyn         625.47
# Bronx            625.27
# Staten Island    625.06
# Manhattan        621.66
# Name: price, dtype: float64
#
# Most expensive neighbourhood to rent from:
# Queens

# %% [markdown]
# ## Task 5a: Data Visualization (Any Tool)
#
# * List the count of various room types avaliable with Airnb
# * Which room type adheres to more strict cancellation policy
# * List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
# * List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood.
# * List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph
# * List the prices with respect to room type using a bar graph and also state your inferences.
# * Create a pie chart that shows  distribution of booked days for each neighborhood group .Which neighborhood has the highest booking percentage.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
##Create a graph to show the count of various room types avaliable with Airnb:

#Create the chart:
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4)) 
ax = sns.countplot(x='room_type', data=df, palette='Set2')

#Add details:
plt.title('Distribution of Room Types\n')
plt.yticks(np.arange(0, 55000, step=5000))
plt.xlabel('\nRoom Type')
plt.ylabel('Count')

##Display Chart
plt.show()

# %%
#Make a bar chat to show which room type adheres to more strict cancellation policy:

#Filter the data:
strict_policy_filter = df[df['cancellation_policy'] == 'strict']
strict_policy_count = strict_policy_filter['room_type'].value_counts()

#Create the chart:
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
sns.barplot(x=strict_policy_count.index, y=strict_policy_count.values, palette='Spectral')

#Add details:
plt.title('Count of Rooms with Strict Policy by Room Type\n')
plt.xlabel('\nRoom Type')
plt.ylabel('Counts')

#Display Chart:
plt.show()

#Calculating the room type that adheres to more strict cancellation policy:
most_strict = strict_policy_count.idxmax()
print('\nThe room type with more strict cancellation policy is:')
print(most_strict)
# Out:
# The room type with more strict cancellation policy is:
# Entire home/apt

# %%
##List the prices by neighbourhood group and also mention which is the most expensive neighborhood group for rentals.

#Group the data by neighbourhood group, calculate the mean price for each group and sort the values:
means = df.groupby('neighbourhood_group')['price'].mean().sort_values(ascending=False)

#Create the chart:
sns.set(style="white")
plt.figure(figsize=(8, 4)) 
ax = sns.barplot(x='neighbourhood_group', y='price', data=df, order=means.index, palette='Spectral')

#Add details
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='center')
plt.title('Average price per Neighborhood Group\n')
plt.xlabel('\nNeighbourhood Group')
plt.ylabel('Average Price')

#Since the means are very similar, the means values were aggregated to enhance the analysis:
room_types = df['room_type'].unique()
for xtick, label in enumerate(ax.get_xticklabels()):
    ax.text(xtick, means[xtick] - 100, f"Mean: ${means[xtick]:.2f}", 
            ha='center', va='top', fontsize=9)
    
#Display chart:
plt.show()

#Calculating the most expensive neighbourhood group:
print("\nMost expensive neighborhood group to rent from:")
print(most_expensive_neighborhood)
# Out:
# Most expensive neighborhood group to rent from:
# Queens

# %%
##List the top 10 neighbourhoods in the increasing order of their price with the help of a horizontal bar graph. 

#Group the data by neighbourhoods, calculate the mean price for each neighbourhood, sort the data and pick the top 10 more expensive:
top_10_neighbourhoods = df.groupby('neighbourhood')['price'].mean().round(2).sort_values(ascending=False).head(10)

#Create the horizontal bar chart
sns.set(style="white")
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_neighbourhoods.values, y=top_10_neighbourhoods.index, palette='magma')

#Add details
plt.xlim(0, 1150)
plt.title('Top 10 Neighbourhoods with Highest Mean Prices\n')
plt.xlabel('\nMean Price')
plt.ylabel('Neighbourhood')

#Add data labels to the bars:
for index, value in enumerate(top_10_neighbourhoods.values):
    plt.text(value, index, f'${value:.2f}', va='center', size='small')
    
#Display Chart
plt.show()

# %%
##Make a graph to show the cheapest neighbourhood:

#Group the data by neighbourhoods, calculate the mean price for each neighbourhood, sort the data and pick the 10 chapest:
top_cheap_neighbourhoods = df.groupby('neighbourhood')['price'].mean().round(2).sort_values(ascending=True).head(10)

#Create the horizontal bar chart
sns.set(style="white")
plt.figure(figsize=(10, 6))
sns.barplot(x=top_cheap_neighbourhoods.values, y=top_cheap_neighbourhoods.index, palette='Spectral')

#Add details
plt.xlim(0, 550)
plt.title('Top 10 Cheapest Neighbourhoods\n')
plt.xlabel('\nMean Price')
plt.ylabel('Neighbourhood')

#Add data labels to the bars:
for index, value in enumerate(top_cheap_neighbourhoods.values):
    plt.text(value, index, f'${value:.2f}', va='center', size='small')
    
#Display Chart
plt.show()

#Display the cheapest neighbourhood :
cheapest = top_cheap_neighbourhoods.idxmin()
print('The cheapest neighbourhood is:')
print(cheapest)
# Out:
# The cheapest neighbourhood is:
# Lighthouse Hill

# %%
##List the neighbourhoods which offer short term rentals within 10 days. Illustrate with a bar graph

#As we can see in the result below, there are a total of 224 different neighbourhoods in the data set and a bar chart is not
#enough to display the information to get useful insights. Instead, I used the neighbourhood group clasification to count the
#amount of properties that are offering short term rental.

short_term_rentals = df[df['minimum_nights'] <= 10]
neighborhood_counts = short_term_rentals.groupby('neighbourhood').size().reset_index(name='property_count')
print(neighborhood_counts)
# Out:
#        neighbourhood  property_count
# 0           Allerton              88
# 1      Arden Heights               6
# 2           Arrochar              49
# 3            Arverne             189
# 4            Astoria            1563
# ..               ...             ...
# 219  Windsor Terrace             273
# 220        Woodhaven             179
# 221         Woodlawn              26
# 222          Woodrow               3
# 223         Woodside             344
#
# [224 rows x 2 columns]

# %%
#Filter the properties that offers a minimum stay of 10 or less days
short_term_rentals = df[df['minimum_nights'] <= 10]

#Group the filtered data by neighbourhood group
neighborhood_counts = short_term_rentals.groupby('neighbourhood_group').size().reset_index(name='property_count')

#Create the chart
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
sns.barplot(x='neighbourhood_group', y='property_count', data=neighborhood_counts, palette='viridis')

#Add details
plt.title('Number of Properties Offering Short-Term Rentals (10 Days or Less)\n')
plt.xlabel('\nNeighbourhood Group')
plt.ylabel('Number of Properties')

#Display the chart
plt.show()

# %%
##List the prices with respect to room type using a bar graph and also state your inferences.

#Group the data by room type and calculate the mean price:
price_by_room_type = df.groupby('room_type')['price'].mean().round(2).sort_values(ascending=False)

#Create the bar chart
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
ax = sns.barplot(x=price_by_room_type.index, y=price_by_room_type.values, palette='YlOrBr')

#Add details
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='center')
plt.title('Prices by room type\n')
plt.xlabel('\nRoom Type')
plt.ylabel('Mean price\n')

room_types = df['room_type'].unique()
for xtick, label in enumerate(ax.get_xticklabels()):
    ax.text(xtick, price_by_room_type[xtick] - 100, f" ${price_by_room_type[xtick]:.2f}", 
            ha='center', va='top', fontsize=9)

#Display Chart
plt.show()

#Inferences:
most_expensive_room = price_by_room_type.idxmax()
print('The room type with most expensive mean prices is:')
print(most_expensive_room)
cheapest_room = price_by_room_type.idxmin()
print('\nThe room type with the cheapest mean price is:')
print(cheapest_room)
price_difference = round(price_by_room_type.max() - price_by_room_type.min(), 2)
print('\nThe difference between the highest and lowest mean prices across all room types is:')
print( '$', price_difference)
price_difference_percentage = round(price_difference / price_by_room_type.max() *100,2)
print("\nThe percentage difference is:")
print(price_difference_percentage,'%')
# Out:
# The room type with most expensive mean prices is:
# Hotel room
#
# The room type with the cheapest mean price is:
# Private room
#
# The difference between the highest and lowest mean prices across all room types is:
# $ 42.55
#
# The percentage difference is:
# 6.39 %

# %%
#Create a pie chart that shows distribution of booked days for each neighborhood group.
#Which neighborhood has the highest booking percentage?

#Group the data and calculate the mean for booked days for each neighbourhood group.
booked_days = df.groupby('neighbourhood_group')['days_booked'].mean().sort_values(ascending=False)

#Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(booked_days, labels=booked_days.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))

#Add details
plt.title('Distribution of Booked Days by Neighborhood Group')
plt.show()

#Display the neighbourhood group with highest booking percentage:
highest_booking_percentage = booked_days.idxmax()
print('The neighborhood group with the highest booking percentage is:')
print(highest_booking_percentage)
# Out:
# The neighborhood group with the highest booking percentage is:
# Staten Island

# %% [markdown]
# ## Task 5b: Data Visualization (Any Tool)
#
# * Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences
# * Using a line graph show in which year the maximum construction of rooms took place.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
##Does service price and room price have an impact on each other?
##Illustrate this relationship with a scatter plot and state your inferences

#Create the chart:
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x="price", y="service_fee")

#Add details:
plt.xlabel('\nRoom Price ($)')
plt.ylabel('Service Fee ($)')
plt.title('Relationship between Service Fee and Room Price\n')
plt.tight_layout()

#Display chart:
plt.show()


#Inferences:
print('The scatter plot clearly illustrates a strong positive correlation between the price and the service fee')
print('As the price increases, there is a corresponding rise in the service fee.')
print('\nThe relationship between price and service fee appears to be linear.')
# Out:
# The scatter plot clearly illustrates a strong positive correlation between the price and the service fee
# As the price increases, there is a corresponding rise in the service fee.
#
# The relationship between price and service fee is linear.

# %%
#Using a line graph show in which year the maximum construction of rooms took place.

#Create a data frame with the count:
construction_year_count = df['construction_year'].value_counts()

#Create the chart:
sns.set(style="darkgrid")
plt.figure(figsize=(8, 4))
ax = sns.lineplot(x=construction_year_count.index, y=construction_year_count.values, palette='Spectral')


plt.xticks(np.arange(2004, 2022, step=1))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title('Construction of Rooms Over the Years\n')
plt.xlabel('\nConstruction Year')
plt.ylabel('Number of rooms constructed')

#Display the chart:
plt.show()

print('The year in which the maximum construction of rooms took place was:')
print(df['construction_year'].value_counts().idxmax())
# Out:
# The year in which the maximum construction of rooms took place was:
# 2012

# %% [markdown]
# # Task 5c: Data Visualization (Any Tool)
#
# * With the help of box plots illustrate the following
# * Effect of Review Rate number on price
# * Effect of host identity verified on price
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
##With the help of box plots illustrate the effect of Review Rate number on price

#Create the chart:
sns.set(style="white")
plt.figure(figsize=(8, 4)) 
ax = sns.boxplot(x='review_rate_number', y='price', data=df, palette='Spectral')

#Add details
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='center')
plt.title('Effect of review rate number on price\n')
plt.xlabel('\nReview Rate Number')
plt.ylabel('Price')

#Since the means are very similar, the values of the box plot means were aggregated to enhance the analysis:
room_types = df['room_type'].unique()
for xtick, label in enumerate(ax.get_xticklabels()):
    ax.text(xtick, means[xtick] - 100, f"Mean: ${means[xtick]:.2f}", 
            ha='center', va='top', fontsize=9)
    
#Display chart:
plt.show()

# %%
##With the help of box plots illustrate the effect of host identity verified on price.

#Create the chart:
sns.set(style="white")
plt.figure(figsize=(8, 4)) 
ax = sns.boxplot(x='host_identity_verified', y='price', data=df, palette='pastel')

#Add details
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='center')
plt.title('Effect of host identity verified on price\n')
plt.xlabel('\nHost Identity Verified')
plt.ylabel('Price')

#Since the means are very similar, the values of the box plot means were aggregated to enhance the analysis:
room_types = df['room_type'].unique()
for xtick, label in enumerate(ax.get_xticklabels()):
    ax.text(xtick, means[xtick] - 100, f"Mean: ${means[xtick]:.2f}", 
            ha='center', va='top', fontsize=9)
    
#Display chart:
plt.show()

# %%
#I also did the last two visualisations in tableau.
#To the export the the cleaned data in a new csv file:
csv_file_path = r'C:\Users\aleja\Documents\Data Analyst\Projects IBM course\cleaned_data.csv'
df.to_csv(csv_file_path, index=False)
